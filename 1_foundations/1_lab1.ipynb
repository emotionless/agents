# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If all Bloops are Razzies and some Razzies are Lazzies, can we definitively conclude that some Bloops are definitely Lazzies? Explain your reasoning.

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the statements and see what conclusions we can draw:
#
# **Given:**
# 1. **All Bloops are Razzies.**
#    This means every Bloop is inside the category of Razzies. In terms of set logic:
#    \( \text{Bloop} \subseteq \text{Razzy} \).
#
# 2. **Some Razzies are Lazzies.**
#    This means there is at least some overlap between the sets Razzies and Lazzies. Symbolically:
#    \( \text{Razzy} \cap \text{Lazzy} \neq \emptyset \).
#
# ---
#
# **Question:**
# Can we definitively conclude that **some Bloops are definitely Lazzies**?
#
# ---
#
# **Reasoning:**
#
# - Since all Bloops are within Razzies, Bloops are a subset of Razzies.
# - Some Razzies overlap with Lazzies, but this "some" does not necessarily include any Bloops.
# - The part of the Razzy set that overlaps with Lazzies could be completely separate from the Bloops subset.
#
# **Visualizing with Venn diagram:**
# - A big circle representing Razzies contains a smaller circle for Bloops inside it.
# - Another circle (for Lazzies) partially overlaps with the Razzies circle.
# - The overlap could be in the area outside the Bloops circle.
#
# ---
#
# **Therefore:**
#
# There is **no guarantee** that the intersection of Razzies and Lazzies includes any Bloops.
#
# Thus, we **cannot definitively conclude** that some Bloops are Lazzies.
#
# ---
#
# ### Summary:
#
# - All Bloops are Razzies.
# - Some Razzies are Lazzies.
# - But **some Razzies** does not mean **some Bloops**.
# - So, it is **not logically certain** that some Bloops are Lazzies.
#
# ---
#
# **Final conclusion:**
# **No, we cannot definitively conclude that some Bloops are Lazzies.**

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's analyze the statements and see what conclusions we can draw:
#
# **Given:**
# 1. **All Bloops are Razzies.**
#    This means every Bloop is inside the category of Razzies. In terms of set logic:
#    \( \text{Bloop} \subseteq \text{Razzy} \).
#
# 2. **Some Razzies are Lazzies.**
#    This means there is at least some overlap between the sets Razzies and Lazzies. Symbolically:
#    \( \text{Razzy} \cap \text{Lazzy} \neq \emptyset \).
#
# ---
#
# **Question:**
# Can we definitively conclude that **some Bloops are definitely Lazzies**?
#
# ---
#
# **Reasoning:**
#
# - Since all Bloops are within Razzies, Bloops are a subset of Razzies.
# - Some Razzies overlap with Lazzies, but this "some" does not necessarily include any Bloops.
# - The part of the Razzy set that overlaps with Lazzies could be completely separate from the Bloops subset.
#
# **Visualizing with Venn diagram:**
# - A big circle representing Razzies contains a smaller circle for Bloops inside it.
# - Another circle (for Lazzies) partially overlaps with the Razzies circle.
# - The overlap could be in the area outside the Bloops circle.
#
# ---
#
# **Therefore:**
#
# There is **no guarantee** that the intersection of Razzies and Lazzies includes any Bloops.
#
# Thus, we **cannot definitively conclude** that some Bloops are Lazzies.
#
# ---
#
# ### Summary:
#
# - All Bloops are Razzies.
# - Some Razzies are Lazzies.
# - But **some Razzies** does not mean **some Bloops**.
# - So, it is **not logically certain** that some Bloops are Lazzies.
#
# ---
#
# **Final conclusion:**
# **No, we cannot definitively conclude that some Bloops are Lazzies.**

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be ripe for an Agentic AI solution."}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content
print (business_idea)
# Out:
# One business area ripe for an Agentic AI solution is **customer service and support in the telecommunications industry**.
#
# ### Why this area?
# - **High volume of repetitive inquiries:** Telecom companies receive millions of customer queries daily, ranging from billing issues and service outages to plan changes.
# - **Complex, dynamic problems:** Customer issues often require navigating multiple systems, policies, and troubleshooting steps.
# - **Demand for 24/7 support:** Customers expect fast, round-the-clock assistance.
# - **Opportunity to reduce costs:** Automating frontline responses and complex tasks can significantly cut operational expenses.
#
# ### How an Agentic AI could help
# - **Autonomous problem-solving:** Rather than just responding to queries, the AI could proactively diagnose connectivity problems by interfacing with network monitoring tools, performing root cause analysis, and even initiating fixes.
# - **Multi-step task handling:** The AI can autonomously manage plan changes, billing adjustments, or device upgrades by interacting with internal systems, verifying customer identity, and confirming actions through dialogue.
# - **Personalized support:** Learning customer preferences and history, the AI can tailor offers or troubleshooting steps to individual needs.
# - **Seamless escalation:** When encountering complex cases beyond its scope, the AI can autonomously escalate and summarize the issue for human agents, improving efficiency.
#
# By deploying an Agentic AI in telecom customer service, companies can dramatically enhance customer experience while reducing human workload and operational costs.

# %%
messages = [{"role": "user", "content": f'{business_idea}. What are the pain points in this industry?'}]

# Then make the first call:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)
pain_points = response.choices[0].message.content
print(pain_points)
# Out:
# The telecommunications industry faces several key pain points in customer service and support, which make it an ideal candidate for Agentic AI solutions:
#
# 1. **High Volume of Customer Interactions**
#    - Millions of daily inquiries create significant workload.
#    - Repetitive and simple questions (e.g., billing, plan info) consume agent time.
#
# 2. **Complexity of Issues**
#    - Problems often span multiple systems (network, billing, CRM).
#    - Troubleshooting requires navigating technical and policy complexities.
#    - Agents must understand diverse products and services.
#
# 3. **Long Wait Times and Limited Availability**
#    - Peak hours and outages lead to long hold times.
#    - Customers expect 24/7 rapid response, which is costly to staff.
#
# 4. **Cost Pressure**
#    - High operational costs for large support teams.
#    - Cost of training and retaining skilled agents.
#    - Need for efficiency without sacrificing service quality.
#
# 5. **Inconsistent Customer Experience**
#    - Variations in agent knowledge and performance.
#    - Lack of personalized support based on customer history or preferences.
#    - Repetitive explanations frustrate customers.
#
# 6. **Escalation Bottlenecks**
#    - Complex cases require escalation to higher tiers.
#    - Delays and loss of context reduce resolution speed.
#    - Inefficient handoffs frustrate both customers and employees.
#
# 7. **Security and Compliance Challenges**
#    - Handling sensitive data demands strict verification processes.
#    - Ensuring compliance with privacy and telecom regulations.
#
# 8. **Integration Difficulties**
#    - Disparate internal systems create barriers for coherent support.
#    - Manual cross-checking across systems slows resolution.
#
# 9. **Proactive Issue Detection and Resolution**
#    - Often issues are only addressed after customer reports.
#    - Lack of real-time network insights correlating with customer complaints.
#
# 10. **Customer Churn Due to Poor Experience**
#     - Unresolved or slow issues lead to dissatisfaction and churn.
#     - Telecom industry is highly competitive; customer retention is critical.
#
# These pain points highlight the complexity, scale, and cost challenges in telecom customer support, underscoring how an Agentic AI could address these effectively through automation, personalization, and proactive problem-solving.

# %%
messages = [{"role": "user", "content": f'What are the solutions for the following pain points? - {business_idea}'}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)
solutions = response.choices[0].message.content
print(solutions)
# Out:
# To address the pain points in customer service and support within the telecommunications industry using Agentic AI, here are tailored solutions aligned with each challenge:
#
# ### 1. High Volume of Repetitive Inquiries
# **Solution:**
# - **Intelligent Autonomous Virtual Agents:** Deploy AI-powered chatbots and voice assistants capable of handling a broad range of routine inquiries (billing questions, service status, plan info) 24/7 without human intervention.
# - **Natural Language Understanding (NLU):** Use advanced NLU to interpret queries accurately and respond accordingly, reducing the need to route to human agents.
#
# ### 2. Complex, Dynamic Problems Requiring Multi-System Navigation
# **Solution:**
# - **Integrated System Access:** Equip the Agentic AI with secure APIs to access multiple backend systems (billing, provisioning, network monitoring) simultaneously.
# - **Autonomous Workflow Automation:** Enable the AI to perform multi-step problem-solving by following predefined processes autonomously, such as verifying identity, checking service status, applying fixes, and updating customer records.
# - **Root Cause Analysis & Proactive Diagnostics:** Have the AI monitor network health data, analyze alerts, and proactively identify issues before customers report them, offering automatic remedies or timely notifications.
#
# ### 3. Demand for 24/7 Support with Fast Response Times
# **Solution:**
# - **Always-On AI Assistants:** AI agents operate continuously with no downtime, responding instantly to customer queries to deliver quick resolutions or informative updates.
# - **Load Balancing Between AI and Human Agents:** The AI handles predictable and routine interactions, freeing human agents to focus on complex cases during all hours, thus improving overall responsiveness.
#
# ### 4. Opportunity to Reduce Costs Through Automation
# **Solution:**
# - **Frontline Automation:** Automate at-scale handling of everyday service requests like plan changes, billing corrections, or device troubleshooting.
# - **Autonomous Escalation and Case Summarization:** When a problem is too complex, the AI automatically escalates cases by summarizing the customer’s issue and prior troubleshooting, reducing call handling times and improving agent effectiveness.
# - **Continuous Learning and Improvement:** Incorporate feedback loops enabling the AI to learn from interactions and human agent resolutions, enhancing accuracy and further minimizing human intervention over time.
#
# ### Additional Benefits from Personalized and Proactive Support
# - **Customer Profiling:** Use historical data and preferences to personalize offers and solutions, increasing customer satisfaction and upsell potential.
# - **Proactive Engagement:** Notify customers of outages, maintenance, or personalized plan optimizations before they contact support, reducing inbound call volume.
#
# ---
#
# ### Summary
#
# | Pain Point                          | Agentic AI Solution                          | Benefits                          |
# |-----------------------------------|---------------------------------------------|----------------------------------|
# | High volume of repetitive inquiries | AI-driven virtual agents with NLU           | Scalability, 24/7 availability   |
# | Complex, dynamic problems           | Integrated multi-system automation           | Faster resolutions, less errors  |
# | Demand for 24/7, fast support       | Always-on AI assistants, load balancing      | Instant response, improved CX    |
# | Reduce operational costs            | Frontline automation and autonomous escalation | Lower costs, higher efficiency   |
# | Need for personalization            | AI-driven customer profiling and proactive engagement | Higher retention and satisfaction |
#
# Implementing an Agentic AI with these capabilities can transform telecom customer service, delivering faster, smarter, and more cost-effective support.

# %%
from IPython.display import Markdown, display

display(Markdown(solutions))
# Out:
# To address the pain points in customer service and support within the telecommunications industry using Agentic AI, here are tailored solutions aligned with each challenge:
#
# ### 1. High Volume of Repetitive Inquiries
# **Solution:**
# - **Intelligent Autonomous Virtual Agents:** Deploy AI-powered chatbots and voice assistants capable of handling a broad range of routine inquiries (billing questions, service status, plan info) 24/7 without human intervention.
# - **Natural Language Understanding (NLU):** Use advanced NLU to interpret queries accurately and respond accordingly, reducing the need to route to human agents.
#
# ### 2. Complex, Dynamic Problems Requiring Multi-System Navigation
# **Solution:**
# - **Integrated System Access:** Equip the Agentic AI with secure APIs to access multiple backend systems (billing, provisioning, network monitoring) simultaneously.
# - **Autonomous Workflow Automation:** Enable the AI to perform multi-step problem-solving by following predefined processes autonomously, such as verifying identity, checking service status, applying fixes, and updating customer records.
# - **Root Cause Analysis & Proactive Diagnostics:** Have the AI monitor network health data, analyze alerts, and proactively identify issues before customers report them, offering automatic remedies or timely notifications.
#
# ### 3. Demand for 24/7 Support with Fast Response Times
# **Solution:**
# - **Always-On AI Assistants:** AI agents operate continuously with no downtime, responding instantly to customer queries to deliver quick resolutions or informative updates.
# - **Load Balancing Between AI and Human Agents:** The AI handles predictable and routine interactions, freeing human agents to focus on complex cases during all hours, thus improving overall responsiveness.
#
# ### 4. Opportunity to Reduce Costs Through Automation
# **Solution:**
# - **Frontline Automation:** Automate at-scale handling of everyday service requests like plan changes, billing corrections, or device troubleshooting.
# - **Autonomous Escalation and Case Summarization:** When a problem is too complex, the AI automatically escalates cases by summarizing the customer’s issue and prior troubleshooting, reducing call handling times and improving agent effectiveness.
# - **Continuous Learning and Improvement:** Incorporate feedback loops enabling the AI to learn from interactions and human agent resolutions, enhancing accuracy and further minimizing human intervention over time.
#
# ### Additional Benefits from Personalized and Proactive Support
# - **Customer Profiling:** Use historical data and preferences to personalize offers and solutions, increasing customer satisfaction and upsell potential.
# - **Proactive Engagement:** Notify customers of outages, maintenance, or personalized plan optimizations before they contact support, reducing inbound call volume.
#
# ---
#
# ### Summary
#
# | Pain Point                          | Agentic AI Solution                          | Benefits                          |
# |-----------------------------------|---------------------------------------------|----------------------------------|
# | High volume of repetitive inquiries | AI-driven virtual agents with NLU           | Scalability, 24/7 availability   |
# | Complex, dynamic problems           | Integrated multi-system automation           | Faster resolutions, less errors  |
# | Demand for 24/7, fast support       | Always-on AI assistants, load balancing      | Instant response, improved CX    |
# | Reduce operational costs            | Frontline automation and autonomous escalation | Lower costs, higher efficiency   |
# | Need for personalization            | AI-driven customer profiling and proactive engagement | Higher retention and satisfaction |
#
# Implementing an Agentic AI with these capabilities can transform telecom customer service, delivering faster, smarter, and more cost-effective support.
