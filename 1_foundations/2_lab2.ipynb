# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# You are an independent expert advising the mayor of a mid-sized coastal city (population 500,000) facing accelerating sea-level rise and more frequent, intense storms. Public funds are limited, low-income neighborhoods are historically under-protected, and the city council is politically divided. Within 1,000 words, produce a 30-year adaptive strategy that: (a) states clear objectives and success metrics; (b) compares at least three distinct approaches (e.g., hard infrastructure, managed retreat, nature-based/hybrid solutions), including order-of-magnitude estimates of up-front and recurring costs and benefits for each; (c) gives a prioritized, time-phased implementation plan with key decision triggers and measurable milestones (when to pivot between approaches); (d) explains how to finance the plan fairly (specific instruments and distributional impacts); (e) identifies the top five uncertainties or failure modes and mitigation measures; and (f) lists your core assumptions and assigns a credible probability (with brief justification) that the chosen primary approach will protect ≥90% of at-risk urban assets by 2055.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Executive summary
# This 30-year adaptive strategy centers on a hybrid, nature-based emphasis with targeted hard protections and managed retreat as a reserved tool. The plan aims to minimize expected annual damages, protect critical assets and vulnerable residents, and maintain fiscal and social equity in a politically divided city of 500,000. It uses iterative triggers to pivot among approaches as climate data and performance evidence accumulate.
#
# (a) Clear objectives and success metrics
# Objectives
# - Reduce annual flood/storm damages in the urban core and vulnerable neighborhoods by at least 60–70% with a flexible mix of protection strategies.
# - Protect high-priority assets (hospitals, schools, emergency services, transit, utilities) and maintain essential services during events.
# - Narrow the protection gap in low-income neighborhoods (increase share with defensible protection by at least 40%).
# - Maintain fiscal sustainability and equity, avoiding disproportionate tax burdens on low-income residents.
#
# Success metrics (30-year horizon)
# - % of at-risk assets afforded protection under the plan (target ≥90% for high-priority assets by 2055 in the most likely scenario).
# - Annual avoided damages (PV) relative to a no-action baseline; target ≥$1–2B of cumulative avoided damages over 30 years in present value for core districts.
# - Number of residents with improved flood/storm resilience (shelter-in-place or retreat options) in lowest-income neighborhoods.
# - Time-to-completion for major milestones (planning, procurement, construction, retrofit) within budget.
# - Equity outcomes: distributional gains measured by insurance premium changes, displacement rates, and affordability metrics.
#
# (b) Approaches compared (with order-of-magnitude costs and benefits)
#
# 1) Hard infrastructure (HU): seawalls, levees, flood barriers, pumped drainage, floodwalls along critical corridors
# - Upfront cost: roughly $2.5–3.5 billion (city-scale, over 5–10 years; with substantial state/federal matching).
# - Recurring costs: ~$100–$200 million/year for O&M, inspection, seismic/repair cycles.
# - Benefits: high direct protection for key assets; significant reduction in storm surge and inland flooding; durable asset resilience; potential insurance premium reductions for protected zones.
# - Limitations/risks: high capital intensity, environmental/shoreline alteration, long permitting cycles, maintenance burden, risk of protection gaps without comprehensive ecosystem integration.
#
# 2) Managed retreat and targeted relocation (MR): buyouts, relocation assistance, zoning adjustments, incentive programs
# - Upfront cost: ~$1.2–2.5 billion (buyouts and early relocation subsidies over 5–15 years).
# - Recurring costs: ~$20–60 million/year (program administration, housing assistance, social services).
# - Benefits: reduces exposure for the most vulnerable/fragile populations and properties; preserves open space and community fabric in the most at-risk zones; lowers long-term hardening needs in those zones.
# - Limitations/risks: political and community opposition; potential displacement and affordability concerns; land-use rewiring challenges; may not address non-residential assets.
#
# 3) Nature-based/hybrid solutions (NBH): living shorelines, wetlands/restoration, dune enhancement, green streets, permeable surfaces, floodable parks
# - Upfront cost: ~$0.6–2.0 billion (pilot-scale to citywide); costs scale with area and maintenance needs.
# - Recurring costs: ~$10–40 million/year (restoration maintenance, vegetation management, monitoring, adaptive maintenance).
# - Benefits: co-benefits (habitat, recreation, water quality, carbon sequestration, cooler urban microclimates); flexibility and lower long-term protection costs; buffers multiple climate hazards; lower social disruption than retreat.
# - Limitations: performance variability under extreme events; long lead times for full ecosystem function; ongoing stewardship and funding required; some areas require complementary hard infrastructure.
#
# (Recommendation: adopt NBH as primary strategy with phased, scalable hard protections in critical nodes and a pre-identified MR option for the most exposed neighborhoods. This hybrid reduces risk from climate surprises and supports equity while providing a faster, modular path to protection.)
#
# (c) Prioritized, time-phased implementation plan (with decision triggers)
#
# Phase A: 0–5 years (foundation)
# - Actions: risk and equity mapping; establish resilience governance (a resilience office or authority); pilot NBH projects (living shorelines, dune restoration, green streets) in 2–3 exposure corridors; begin protected-site selection for hardening; start community engagement focused on low-income neighborhoods.
# - Milestones: baseline vulnerability inventory; pilot NBH sites fully designed; initial buyout/relocation framework ready for a subset of lowest-income zones; funding plan and bonds issued for initial NBH and small-scale hardening.
# - Decision triggers: if NBH pilots underperform predicted flood reduction by >25% in major events, pivot to more aggressive hybrid hardening in those segments; if equity indicators lag, accelerate targeted MR with expanded housing support.
#
# Phase B: 5–10 years (scale NBH; advance selective hardening)
# - Actions: expand NBH networks; implement green/blue infrastructure in city corridors; begin hardening at critical assets (hospitals, wastewater, pumping stations) with modular seawalls or flood barriers; launch targeted MR (voluntary buyouts) in highest-risk neighborhoods; formalize funding streams.
# - Milestones: 25–40% of high-risk zones NBH-protected; critical asset ring hardened; first wave of buyouts completed; financing tools in place for long-term capital.
# - Decision triggers: if protective performance against design storms remains below targets, escalate hardening in additional corridors; if political consensus falters, pause non-essential MR and reallocate to NBH/hardening.
#
# Phase C: 10–20 years (integrated protection; adaptive management)
# - Actions: complete major NBH networks; implement major hardening where cost-effective; complete remainder MR programs where benefits exceed costs; implement floodable parks and water-sensitive urban design citywide.
# - Milestones: protection of majority of at-risk assets in core districts; significant expansion of protective NBH in fringe communities; insurance/premium reductions realized in protected areas.
# - Decision triggers: if climate data indicate new risk profiles or if MR uptake stalls, adjust incentives; if procurement or construction costs spike, trigger value-engineering reviews and extended financing strategies.
#
# Phase D: 20–30 years (assessment and adaptation)
# - Actions: performance review; retrofits to meet updated climate projections; adjust protection mix as needed; scale monitoring; ensure long-term maintenance and equity safeguards.
# - Milestones: ≥90% of prioritized assets protected; resilience monitoring system operational; outcomes report showing reduced damages and improved equity metrics.
# - Decision triggers: if 2055 protection target is not on track, implement rapid deployment of additional NBH or restore MR options with updated incentives.
#
# (d) Financing the plan fairly (instruments and distributional impact)
#
# - Capital instruments
#   - General obligation bonds (GO): long-term funding for NBH and selective hard infrastructure; repaid via property taxes; prioritize equitable allocation to disadvantaged neighborhoods.
#   - Resilience bonds / catastrophe bonds: transfer risk to markets; align with insurance savings.
#   - Federal/state grants and programs: FEMA HMA/BRIC, HUD CDBG-DR/HOME, NOAA; seek multi-year commitments and tied resilience planning.
#   - Public-private partnerships (P3) and developer obligations: impact fees, density bonuses linked to resilience improvements; reinvestment requirements in nearshore districts.
#   - Stormwater utility charges: modest, progressive rate structure to fund NBH and green infrastructure; ensure exemptions or caps for very low-income residents.
#   - Reinvested insurance and disaster recovery windfalls: reserve funds for hardening in subsequent cycles.
#
# - Distributional safeguards
#   - Reserve at least 25–40% of resilience funds for low-income neighborhoods; prioritize home buyouts, relocation assistance, and rent-support programs.
#   - Anti-displacement measures: affordable-housing protections, tenant-rights advocacy, and community benefit agreements with developers.
#   - Transparent oversight: independent equity advisory board, public dashboards, annual progress reports.
#
# (e) Top five uncertainties and mitigation measures
# 1) Climate projections and extreme events: uncertainty in SLR and storm intensity.
#    - Mitigation: design with modularity, adaptive thresholds, staged deployments, and regular re-evaluation every 5–7 years.
# 2) Financing gaps and political gridlock.
#    - Mitigation: diversify funding (federal/state grants, resilience bonds, private contributions), establish a resilience fund with dedicated revenue streams.
# 3) Public opposition to retreat/displacement.
#    - Mitigation: robust, early community engagement; fair compensation, mobility and housing assistance, clear non-displacement commitments where feasible.
# 4) NBH performance under extreme events and maintenance burden.
#    - Mitigation: durable designs, long-term maintenance contracts, adaptive management, robust monitoring, and rapid repair provisions.
# 5) Equity and displacement risks.
#    - Mitigation: explicit equity targets, rent/price controls around protected zones, anti-displacement programs, community land trusts, and inclusive decision-making.
#
# (f) Core assumptions and probability of protection
# Core assumptions
# - SLR and storm intensities follow mid-to-high warming scenarios but with adaptive protections capable of upgrading every 5–7 years.
# - Population remains around 500,000 with modest migration; housing affordability policies are in place.
# - Technology costs trend with current trajectories for NBH and modular hardening; financing markets remain accessible.
# - Federal/state support remains available and implementing agencies meet procurement timelines.
#
# Probability estimate for primary approach
# - Primary approach: Nature-based/hybrid with targeted hardening and MR as a contingency.
# - Credible probability that this primary approach will protect ≥90% of at-risk urban assets by 2055: about 70–80%, with about a 20–30% chance that more aggressive hardening or greater retreat becomes necessary due to climate surprises or funding shortfalls.
# Rationale: NBH plus selective hardening provides flexible, scalable protection, aligns with multiple co-benefits (ecology, recreation, water quality), and can be deployed incrementally while expanding protections. Displacement risk is mitigated with targeted MR and robust equity safeguards. The remaining risk hinges on extreme events beyond design, funding volatility, or political inertia.
#
# If you’d like, I can tailor the cost ranges, milestones, and equity targets to your city’s actual budget, tax structure, and FEMA/State grant programs, and draft a concise one-page decision matrix to facilitate council votes.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       3 model_name = "claude-sonnet-4-5"
#       5 claude = Anthropic()
# ----> 6 response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
#       7 answer = response.content[0].text
#       9 display(Markdown(answer))
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:930, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     923 if model in DEPRECATED_MODELS:
#     924     warnings.warn(
#     925         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     926         DeprecationWarning,
#     927         stacklevel=3,
#     928     )
# --> 930 return self._post(
#     931     "/v1/messages",
#     932     body=maybe_transform(
#     933         {
#     934             "max_tokens": max_tokens,
#     935             "messages": messages,
#     936             "model": model,
#     937             "metadata": metadata,
#     938             "service_tier": service_tier,
#     939             "stop_sequences": stop_sequences,
#     940             "stream": stream,
#     941             "system": system,
#     942             "temperature": temperature,
#     943             "thinking": thinking,
#     944             "tool_choice": tool_choice,
#     945             "tools": tools,
#     946             "top_k": top_k,
#     947             "top_p": top_p,
#     948         },
#     949         message_create_params.MessageCreateParamsStreaming
#     950         if stream
#     951         else message_create_params.MessageCreateParamsNonStreaming,
#     952     ),
#     953     options=make_request_options(
#     954         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     955     ),
#     956     cast_to=Message,
#     957     stream=stream or False,
#     958     stream_cls=Stream[RawMessageStreamEvent],
#     959 )
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1324, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1310 def post(
#    1311     self,
#    1312     path: str,
#    (...)   1319     stream_cls: type[_StreamT] | None = None,
#    1320 ) -> ResponseT | _StreamT:
#    1321     opts = FinalRequestOptions.construct(
#    1322         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1323     )
# -> 1324     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1033, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1030 options = self._prepare_options(options)
#    1032 remaining_retries = max_retries - retries_taken
# -> 1033 request = self._build_request(options, retries_taken=retries_taken)
#    1034 self._prepare_request(request)
#    1036 kwargs: HttpxSendArgs = {}
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:506, in BaseClient._build_request(self, options, retries_taken)
#     503     else:
#     504         raise RuntimeError(f"Unexpected JSON data type, {type(json_data)}, cannot merge with `extra_body`")
# --> 506 headers = self._build_headers(options, retries_taken=retries_taken)
#     507 params = _merge_mappings(self.default_query, options.params)
#     508 content_type = headers.get("Content-Type")
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:447, in BaseClient._build_headers(self, options, retries_taken)
#     437 custom_headers = options.headers or {}
#     438 headers_dict = _merge_mappings(
#     439     {
#     440         "x-stainless-timeout": str(options.timeout.read)
#    (...)    445     custom_headers,
#     446 )
# --> 447 self._validate_headers(headers_dict, custom_headers)
#     449 # headers are case-insensitive while dictionaries are not.
#     450 headers = httpx.Headers(headers_dict)
#
# File ~/projects/agents/.venv/lib/python3.12/site-packages/anthropic/_client.py:196, in Anthropic._validate_headers(self, headers, custom_headers)
#     193 if isinstance(custom_headers.get("Authorization"), Omit):
#     194     return
# --> 196 raise TypeError(
#     197     '"Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"'
#     198 )
#
# TypeError: "Could not resolve authentication method. Expected either api_key or auth_token to be set. Or for one of the `X-Api-Key` or `Authorization` headers to be explicitly omitted"

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gpt-5-nano']
# ['Executive summary\nThis 30-year adaptive strategy centers on a hybrid, nature-based emphasis with targeted hard protections and managed retreat as a reserved tool. The plan aims to minimize expected annual damages, protect critical assets and vulnerable residents, and maintain fiscal and social equity in a politically divided city of 500,000. It uses iterative triggers to pivot among approaches as climate data and performance evidence accumulate.\n\n(a) Clear objectives and success metrics\nObjectives\n- Reduce annual flood/storm damages in the urban core and vulnerable neighborhoods by at least 60–70% with a flexible mix of protection strategies.\n- Protect high-priority assets (hospitals, schools, emergency services, transit, utilities) and maintain essential services during events.\n- Narrow the protection gap in low-income neighborhoods (increase share with defensible protection by at least 40%).\n- Maintain fiscal sustainability and equity, avoiding disproportionate tax burdens on low-income residents.\n\nSuccess metrics (30-year horizon)\n- % of at-risk assets afforded protection under the plan (target ≥90% for high-priority assets by 2055 in the most likely scenario).\n- Annual avoided damages (PV) relative to a no-action baseline; target ≥$1–2B of cumulative avoided damages over 30 years in present value for core districts.\n- Number of residents with improved flood/storm resilience (shelter-in-place or retreat options) in lowest-income neighborhoods.\n- Time-to-completion for major milestones (planning, procurement, construction, retrofit) within budget.\n- Equity outcomes: distributional gains measured by insurance premium changes, displacement rates, and affordability metrics.\n\n(b) Approaches compared (with order-of-magnitude costs and benefits)\n\n1) Hard infrastructure (HU): seawalls, levees, flood barriers, pumped drainage, floodwalls along critical corridors\n- Upfront cost: roughly $2.5–3.5 billion (city-scale, over 5–10 years; with substantial state/federal matching).\n- Recurring costs: ~$100–$200 million/year for O&M, inspection, seismic/repair cycles.\n- Benefits: high direct protection for key assets; significant reduction in storm surge and inland flooding; durable asset resilience; potential insurance premium reductions for protected zones.\n- Limitations/risks: high capital intensity, environmental/shoreline alteration, long permitting cycles, maintenance burden, risk of protection gaps without comprehensive ecosystem integration.\n\n2) Managed retreat and targeted relocation (MR): buyouts, relocation assistance, zoning adjustments, incentive programs\n- Upfront cost: ~$1.2–2.5 billion (buyouts and early relocation subsidies over 5–15 years).\n- Recurring costs: ~$20–60 million/year (program administration, housing assistance, social services).\n- Benefits: reduces exposure for the most vulnerable/fragile populations and properties; preserves open space and community fabric in the most at-risk zones; lowers long-term hardening needs in those zones.\n- Limitations/risks: political and community opposition; potential displacement and affordability concerns; land-use rewiring challenges; may not address non-residential assets.\n\n3) Nature-based/hybrid solutions (NBH): living shorelines, wetlands/restoration, dune enhancement, green streets, permeable surfaces, floodable parks\n- Upfront cost: ~$0.6–2.0 billion (pilot-scale to citywide); costs scale with area and maintenance needs.\n- Recurring costs: ~$10–40 million/year (restoration maintenance, vegetation management, monitoring, adaptive maintenance).\n- Benefits: co-benefits (habitat, recreation, water quality, carbon sequestration, cooler urban microclimates); flexibility and lower long-term protection costs; buffers multiple climate hazards; lower social disruption than retreat.\n- Limitations: performance variability under extreme events; long lead times for full ecosystem function; ongoing stewardship and funding required; some areas require co ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gpt-5-nano
#
# Executive summary
# This 30-year adaptive strategy centers on a hybrid, nature-based emphasis with targeted hard protections and managed retreat as a reserved tool. The plan aims to minimize expected annual damages, protect critical assets and vulnerable residents, and maintain fiscal and social equity in a politically divided city of 500,000. It uses iterative triggers to pivot among approaches as climate data and performance evidence accumulate.
#
# (a) Clear objectives and success metrics
# Objectives
# - Reduce annual flood/storm damages in the urban core and vulnerable neighborhoods by at least 60–70% with a flexible mix of protection strategies.
# - Protect high-priority assets (hospitals, schools, emergency services, transit, utilities) and maintain essential services during events.
# - Narrow the protection gap in low-income neighborhoods (increase share with defensible protection by at least 40%).
# - Maintain fiscal sustainability and equity, avoiding disproportionate tax burdens on low-income residents.
#
# Success metrics (30-year horizon)
# - % of at-risk assets afforded protection under the plan (target ≥90% for high-priority assets by 2055 in the most likely scenario).
# - Annual avoided damages (PV) relative to a no-action baseline; target ≥$1–2B of cumulative avoided damages over 30 years in present value for core districts.
# - Number of residents with improved flood/storm resilience (shelter-in-place or retreat options) in lowest-income neighborhoods.
# - Time-to-completion for major milestones (planning, procurement, construction, retrofit) within budget.
# - Equity outcomes: distributional gains measured by insurance premium changes, displacement rates, and affordability metrics.
#
# (b) Approaches compared (with order-of-magnitude costs and benefits)
#
# 1) Hard infrastructure (HU): seawalls, levees, flood barriers, pumped drainage, floodwalls along critical corridors
# - Upfront cost: roughly $2.5–3.5 billion (city-scale, over 5–10 years; with substantial state/federal matching).
# - Recurring costs: ~$100–$200 million/year for O&M, inspection, seismic/repair cycles.
# - Benefits: high direct protection for key assets; significant reduction in storm surge and inland flooding; durable asset resilience; potential insurance premium reductions for protected zones.
# - Limitations/risks: high capital intensity, environmental/shoreline alteration, long permitting cycles, maintenance burden, risk of protection gaps without comprehensive ecosystem integration.
#
# 2) Managed retreat and targeted relocation (MR): buyouts, relocation assistance, zoning adjustments, incentive programs
# - Upfront cost: ~$1.2–2.5 billion (buyouts and early relocation subsidies over 5–15 years).
# - Recurring costs: ~$20–60 million/year (program administration, housing assistance, social services).
# - Benefits: reduces exposure for the most vulnerable/fragile populations and properties; preserves open space and community fabric in the most at-risk zones; lowers long-term hardening needs in those zones.
# - Limitations/risks: political and community opposition; potential displacement and affordability concerns; land-use rewiring challenges; may not address non-residential assets.
#
# 3) Nature-based/hybrid solutions (NBH): living shorelines, wetlands/restoration, dune enhancement, green streets, permeable surfaces, floodable parks
# - Upfront cost: ~$0.6–2.0 billion (pilot-scale to citywide); costs scale with area and maintenance needs.
# - Recurring costs: ~$10–40 million/year (restoration maintenance, vegetation management, monitoring, adaptive maintenance).
# - Benefits: co-benefits (habitat, recreation, water quality, carbon sequestration, cooler urban microclimates); flexibility and lower long-term protection costs; buffers multiple climate hazards; lower social disruption than retreat.
# - Limitations: performance variability under extreme events; long lead times for full ecosystem function; ongoing stewardship and funding required; some areas require complementary hard infrastructure.
#
# (Recommendation: adopt NBH as primary strategy with phased, scalable hard protections in critical nodes and a pre-identified MR option for the most exposed neighborhoods. This hybrid reduces risk from climate surprises and supports equity while providing a faster, modular path to protection.)
#
# (c) Prioritized, time-phased implementation plan (with decision triggers)
#
# Phase A: 0–5 years (foundation)
# - Actions: risk and equity mapping; establish resilience governance (a resilience office or authority); pilot NBH projects (living shorelines, dune restoration, green streets) in 2–3 exposure corridors; begin protected-site selection for hardening; start community engagement focused on low-income neighborhoods.
# - Milestones: baseline vulnerability inventory; pilot NBH sites fully designed; initial buyout/relocation framework ready for a subset of lowest-income zones; funding plan and bonds issued for initial NBH and small-scale hardening.
# - Decision triggers: if NBH pilots underperform predicted flood reduction by >25% in major events, pivot to more aggressive hybrid hardening in those segments; if equity indicators lag, accelerate targeted MR with expanded housing support.
#
# Phase B: 5–10 years (scale NBH; advance selective hardening)
# - Actions: expand NBH networks; implement green/blue infrastructure in city corridors; begin hardening at critical assets (hospitals, wastewater, pumping stations) with modular seawalls or flood barriers; launch targeted MR (voluntary buyouts) in highest-risk neighborhoods; formalize funding streams.
# - Milestones: 25–40% of high-risk zones NBH-protected; critical asset ring hardened; first wave of buyouts completed; financing tools in place for long-term capital.
# - Decision triggers: if protective performance against design storms remains below targets, escalate hardening in additional corridors; if political consensus falters, pause non-essential MR and reallocate to NBH/hardening.
#
# Phase C: 10–20 years (integrated protection; adaptive management)
# - Actions: complete major NBH networks; implement major hardening where cost-effective; complete remainder MR programs where benefits exceed costs; implement floodable parks and water-sensitive urban design citywide.
# - Milestones: protection of majority of at-risk assets in core districts; significant expansion of protective NBH in fringe communities; insurance/premium reductions realized in protected areas.
# - Decision triggers: if climate data indicate new risk profiles or if MR uptake stalls, adjust incentives; if procurement or construction costs spike, trigger value-engineering reviews and extended financing strategies.
#
# Phase D: 20–30 years (assessment and adaptation)
# - Actions: performance review; retrofits to meet updated climate projections; adjust protection mix as needed; scale monitoring; ensure long-term maintenance and equity safeguards.
# - Milestones: ≥90% of prioritized assets protected; resilience monitoring system operational; outcomes report showing reduced damages and improved equity metrics.
# - Decision triggers: if 2055 protection target is not on track, implement rapid deployment of additional NBH or restore MR options with updated incentives.
#
# (d) Financing the plan fairly (instruments and distributional impact)
#
# - Capital instruments
#   - General obligation bonds (GO): long-term funding for NBH and selective hard infrastructure; repaid via property taxes; prioritize equitable allocation to disadvantaged neighborhoods.
#   - Resilience bonds / catastrophe bonds: transfer risk to markets; align with insurance savings.
#   - Federal/state grants and programs: FEMA HMA/BRIC, HUD CDBG-DR/HOME, NOAA; seek multi-year commitments and tied resilience planning.
#   - Public-private partnerships (P3) and developer obligations: impact fees, density bonuses linked to resilience improvements; reinvestment requirements in nearshore districts.
#   - Stormwater utility charges: modest, progressive rate structure to fund NBH and green infrastructure; ensure exemptions or caps for very low-income residents.
#   - Reinvested insurance and disaster recovery windfalls: reserve funds for hardening in subsequent cycles.
#
# - Distributional safeguards
#   - Reserve at least 25–40% of resilience funds for low-income neighborhoods; prioritize home buyouts, relocation assistance, and rent-support programs.
#   - Anti-displacement measures: affordable-housing protections, tenant-rights advocacy, and community benefit agreements with developers.
#   - Transparent oversight: independent equity advisory board, public dashboards, annual progress reports.
#
# (e) Top five uncertainties and mitigation measures
# 1) Climate projections and extreme events: uncertainty in SLR and storm intensity.
#    - Mitigation: design with modularity, adaptive thresholds, staged deployments, and regular re-evaluation every 5–7 years.
# 2) Financing gaps and political gridlock.
#    - Mitigation: diversify funding (federal/state grants, resilience bonds, private contributions), establish a resilience fund with dedicated revenue streams.
# 3) Public opposition to retreat/displacement.
#    - Mitigation: robust, early community engagement; fair compensation, mobility and housing assistance, clear non-displacement commitments where feasible.
# 4) NBH performance under extreme events and maintenance burden.
#    - Mitigation: durable designs, long-term maintenance contracts, adaptive management, robust monitoring, and rapid repair provisions.
# 5) Equity and displacement risks.
#    - Mitigation: explicit equity targets, rent/price controls around protected zones, anti-displacement programs, community land trusts, and inclusive decision-making.
#
# (f) Core assumptions and probability of protection
# Core assumptions
# - SLR and storm intensities follow mid-to-high warming scenarios but with adaptive protections capable of upgrading every 5–7 years.
# - Population remains around 500,000 with modest migration; housing affordability policies are in place.
# - Technology costs trend with current trajectories for NBH and modular hardening; financing markets remain accessible.
# - Federal/state support remains available and implementing agencies meet procurement timelines.
#
# Probability estimate for primary approach
# - Primary approach: Nature-based/hybrid with targeted hardening and MR as a contingency.
# - Credible probability that this primary approach will protect ≥90% of at-risk urban assets by 2055: about 70–80%, with about a 20–30% chance that more aggressive hardening or greater retreat becomes necessary due to climate surprises or funding shortfalls.
# Rationale: NBH plus selective hardening provides flexible, scalable protection, aligns with multiple co-benefits (ecology, recreation, water quality), and can be deployed incrementally while expanding protections. Displacement risk is mitigated with targeted MR and robust equity safeguards. The remaining risk hinges on extreme events beyond design, funding volatility, or political inertia.
#
# If you’d like, I can tailor the cost ranges, milestones, and equity targets to your city’s actual budget, tax structure, and FEMA/State grant programs, and draft a concise one-page decision matrix to facilitate council votes.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# Executive summary
# This 30-year adaptive strategy centers on a hybrid, nature-based emphasis with targeted hard protections and managed retreat as a reserved tool. The plan aims to minimize expected annual damages, protect critical assets and vulnerable residents, and maintain fiscal and social equity in a politically divided city of 500,000. It uses iterative triggers to pivot among approaches as climate data and performance evidence accumulate.
#
# (a) Clear objectives and success metrics
# Objectives
# - Reduce annual flood/storm damages in the urban core and vulnerable neighborhoods by at least 60–70% with a flexible mix of protection strategies.
# - Protect high-priority assets (hospitals, schools, emergency services, transit, utilities) and maintain essential services during events.
# - Narrow the protection gap in low-income neighborhoods (increase share with defensible protection by at least 40%).
# - Maintain fiscal sustainability and equity, avoiding disproportionate tax burdens on low-income residents.
#
# Success metrics (30-year horizon)
# - % of at-risk assets afforded protection under the plan (target ≥90% for high-priority assets by 2055 in the most likely scenario).
# - Annual avoided damages (PV) relative to a no-action baseline; target ≥$1–2B of cumulative avoided damages over 30 years in present value for core districts.
# - Number of residents with improved flood/storm resilience (shelter-in-place or retreat options) in lowest-income neighborhoods.
# - Time-to-completion for major milestones (planning, procurement, construction, retrofit) within budget.
# - Equity outcomes: distributional gains measured by insurance premium changes, displacement rates, and affordability metrics.
#
# (b) Approaches compared (with order-of-magnitude costs and benefits)
#
# 1) Hard infrastructure (HU): seawalls, levees, flood barriers, pumped drainage, floodwalls along critical corridors
# - Upfront cost: roughly $2.5–3.5 billion (city-scale, over 5–10 years; with substantial state/federal matching).
# - Recurring costs: ~$100–$200 million/year for O&M, inspection, seismic/repair cycles.
# - Benefits: high direct protection for key assets; significant reduction in storm surge and inland flooding; durable asset resilience; potential insurance premium reductions for protected zones.
# - Limitations/risks: high capital intensity, environmental/shoreline alteration, long permitting cycles, maintenance burden, risk of protection gaps without comprehensive ecosystem integration.
#
# 2) Managed retreat and targeted relocation (MR): buyouts, relocation assistance, zoning adjustments, incentive programs
# - Upfront cost: ~$1.2–2.5 billion (buyouts and early relocation subsidies over 5–15 years).
# - Recurring costs: ~$20–60 million/year (program administration, housing assistance, social services).
# - Benefits: reduces exposure for the most vulnerable/fragile populations and properties; preserves open space and community fabric in the most at-risk zones; lowers long-term hardening needs in those zones.
# - Limitations/risks: political and community opposition; potential displacement and affordability concerns; land-use rewiring challenges; may not address non-residential assets.
#
# 3) Nature-based/hybrid solutions (NBH): living shorelines, wetlands/restoration, dune enhancement, green streets, permeable surfaces, floodable parks
# - Upfront cost: ~$0.6–2.0 billion (pilot-scale to citywide); costs scale with area and maintenance needs.
# - Recurring costs: ~$10–40 million/year (restoration maintenance, vegetation management, monitoring, adaptive maintenance).
# - Benefits: co-benefits (habitat, recreation, water quality, carbon sequestration, cooler urban microclimates); flexibility and lower long-term protection costs; buffers multiple climate hazards; lower social disruption than retreat.
# - Limitations: performance variability under extreme events; long lead times for full ecosystem function; ongoing stewardship and funding required; some areas require complementary hard infrastructure.
#
# (Recommendation: adopt NBH as primary strategy with phased, scalable hard protections in critical nodes and a pre-identified MR option for the most exposed neighborhoods. This hybrid reduces risk from climate surprises and supports equity while providing a faster, modular path to protection.)
#
# (c) Prioritized, time-phased implementation plan (with decision triggers)
#
# Phase A: 0–5 years (foundation)
# - Actions: risk and equity mapping; establish resilience governance (a resilience office or authority); pilot NBH projects (living shorelines, dune restoration, green streets) in 2–3 exposure corridors; begin protected-site selection for hardening; start community engagement focused on low-income neighborhoods.
# - Milestones: baseline vulnerability inventory; pilot NBH sites fully designed; initial buyout/relocation framework ready for a subset of lowest-income zones; funding plan and bonds issued for initial NBH and small-scale hardening.
# - Decision triggers: if NBH pilots underperform predicted flood reduction by >25% in major events, pivot to more aggressive hybrid hardening in those segments; if equity indicators lag, accelerate targeted MR with expanded housing support.
#
# Phase B: 5–10 years (scale NBH; advance selective hardening)
# - Actions: expand NBH networks; implement green/blue infrastructure in city corridors; begin hardening at critical assets (hospitals, wastewater, pumping stations) with modular seawalls or flood barriers; launch targeted MR (voluntary buyouts) in highest-risk neighborhoods; formalize funding streams.
# - Milestones: 25–40% of high-risk zones NBH-protected; critical asset ring hardened; first wave of buyouts completed; financing tools in place for long-term capital.
# - Decision triggers: if protective performance against design storms remains below targets, escalate hardening in additional corridors; if political consensus falters, pause non-essential MR and reallocate to NBH/hardening.
#
# Phase C: 10–20 years (integrated protection; adaptive management)
# - Actions: complete major NBH networks; implement major hardening where cost-effective; complete remainder MR programs where benefits exceed costs; implement floodable parks and water-sensitive urban design citywide.
# - Milestones: protection of majority of at-risk assets in core districts; significant expansion of protective NBH in fringe communities; insurance/premium reductions realized in protected areas.
# - Decision triggers: if climate data indicate new risk profiles or if MR uptake stalls, adjust incentives; if procurement or construction costs spike, trigger value-engineering reviews and extended financing strategies.
#
# Phase D: 20–30 years (assessment and adaptation)
# - Actions: performance review; retrofits to meet updated climate projections; adjust protection mix as needed; scale monitoring; ensure long-term maintenance and equity safeguards.
# - Milestones: ≥90% of prioritized assets protected; resilience monitoring system operational; outcomes report showing reduced damages and improved equity metrics.
# - Decision triggers: if 2055 protection target is not on track, implement rapid deployment of additional NBH or restore MR options with updated incentives.
#
# (d) Financing the plan fairly (instruments and distributional impact)
#
# - Capital instruments
#   - General obligation bonds (GO): long-term funding for NBH and selective hard infrastructure; repaid via property taxes; prioritize equitable allocation to disadvantaged neighborhoods.
#   - Resilience bonds / catastrophe bonds: transfer risk to markets; align with insurance savings.
#   - Federal/state grants and programs: FEMA HMA/BRIC, HUD CDBG-DR/HOME, NOAA; seek multi-year commitments and tied resilience planning.
#   - Public-private partnerships (P3) and developer obligations: impact fees, density bonuses linked to resilience improvements; reinvestment requirements in nearshore districts.
#   - Stormwater utility charges: modest, progressive rate structure to fund NBH and green infrastructure; ensure exemptions or caps for very low-income residents.
#   - Reinvested insurance and disaster recovery windfalls: reserve funds for hardening in subsequent cycles.
#
# - Distributional safeguards
#   - Reserve at least 25–40% of resilience funds for low-income neighborhoods; prioritize home buyouts, relocation assistance, and rent-support programs.
#   - Anti-displacement measures: affordable-housing protections, tenant-rights advocacy, and community benefit agreements with developers.
#   - Transparent oversight: independent equity advisory board, public dashboards, annual progress reports.
#
# (e) Top five uncertainties and mitigation measures
# 1) Climate projections and extreme events: uncertainty in SLR and storm intensity.
#    - Mitigation: design with modularity, adaptive thresholds, staged deployments, and regular re-evaluation every 5–7 years.
# 2) Financing gaps and political gridlock.
#    - Mitigation: diversify funding (federal/state grants, resilience bonds, private contributions), establish a resilience fund with dedicated revenue streams.
# 3) Public opposition to retreat/displacement.
#    - Mitigation: robust, early community engagement; fair compensation, mobility and housing assistance, clear non-displacement commitments where feasible.
# 4) NBH performance under extreme events and maintenance burden.
#    - Mitigation: durable designs, long-term maintenance contracts, adaptive management, robust monitoring, and rapid repair provisions.
# 5) Equity and displacement risks.
#    - Mitigation: explicit equity targets, rent/price controls around protected zones, anti-displacement programs, community land trusts, and inclusive decision-making.
#
# (f) Core assumptions and probability of protection
# Core assumptions
# - SLR and storm intensities follow mid-to-high warming scenarios but with adaptive protections capable of upgrading every 5–7 years.
# - Population remains around 500,000 with modest migration; housing affordability policies are in place.
# - Technology costs trend with current trajectories for NBH and modular hardening; financing markets remain accessible.
# - Federal/state support remains available and implementing agencies meet procurement timelines.
#
# Probability estimate for primary approach
# - Primary approach: Nature-based/hybrid with targeted hardening and MR as a contingency.
# - Credible probability that this primary approach will protect ≥90% of at-risk urban assets by 2055: about 70–80%, with about a 20–30% chance that more aggressive hardening or greater retreat becomes necessary due to climate surprises or funding shortfalls.
# Rationale: NBH plus selective hardening provides flexible, scalable protection, aligns with multiple co-benefits (ecology, recreation, water quality), and can be deployed incrementally while expanding protections. Displacement risk is mitigated with targeted MR and robust equity safeguards. The remaining risk hinges on extreme events beyond design, funding volatility, or political inertia.
#
# If you’d like, I can tailor the cost ranges, milestones, and equity targets to your city’s actual budget, tax structure, and FEMA/State grant programs, and draft a concise one-page decision matrix to facilitate council votes.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 1 competitors.
# Each model has been given this question:
#
# You are an independent expert advising the mayor of a mid-sized coastal city (population 500,000) facing accelerating sea-level rise and more frequent, intense storms. Public funds are limited, low-income neighborhoods are historically under-protected, and the city council is politically divided. Within 1,000 words, produce a 30-year adaptive strategy that: (a) states clear objectives and success metrics; (b) compares at least three distinct approaches (e.g., hard infrastructure, managed retreat, nature-based/hybrid solutions), including order-of-magnitude estimates of up-front and recurring costs and benefits for each; (c) gives a prioritized, time-phased implementation plan with key decision triggers and measurable milestones (when to pivot between approaches); (d) explains how to finance the plan fairly (specific instruments and distributional impacts); (e) identifies the top five uncertainties or failure modes and mitigation measures; and (f) lists your core assumptions and assigns a credible probability (with brief justification) that the chosen primary approach will protect ≥90% of at-risk urban assets by 2055.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# Executive summary
# This 30-year adaptive strategy centers on a hybrid, nature-based emphasis with targeted hard protections and managed retreat as a reserved tool. The plan aims to minimize expected annual damages, protect critical assets and vulnerable residents, and maintain fiscal and social equity in a politically divided city of 500,000. It uses iterative triggers to pivot among approaches as climate data and performance evidence accumulate.
#
# (a) Clear objectives and success metrics
# Objectives
# - Reduce annual flood/storm damages in the urban core and vulnerable neighborhoods by at least 60–70% with a flexible mix of protection strategies.
# - Protect high-priority assets (hospitals, schools, emergency services, transit, utilities) and maintain essential services during events.
# - Narrow the protection gap in low-income neighborhoods (increase share with defensible protection by at least 40%).
# - Maintain fiscal sustainability and equity, avoiding disproportionate tax burdens on low-income residents.
#
# Success metrics (30-year horizon)
# - % of at-risk assets afforded protection under the plan (target ≥90% for high-priority assets by 2055 in the most likely scenario).
# - Annual avoided damages (PV) relative to a no-action baseline; target ≥$1–2B of cumulative avoided damages over 30 years in present value for core districts.
# - Number of residents with improved flood/storm resilience (shelter-in-place or retreat options) in lowest-income neighborhoods.
# - Time-to-completion for major milestones (planning, procurement, construction, retrofit) within budget.
# - Equity outcomes: distributional gains measured by insurance premium changes, displacement rates, and affordability metrics.
#
# (b) Approaches compared (with order-of-magnitude costs and benefits)
#
# 1) Hard infrastructure (HU): seawalls, levees, flood barriers, pumped drainage, floodwalls along critical corridors
# - Upfront cost: roughly $2.5–3.5 billion (city-scale, over 5–10 years; with substantial state/federal matching).
# - Recurring costs: ~$100–$200 million/year for O&M, inspection, seismic/repair cycles.
# - Benefits: high direct protection for key assets; significant reduction in storm surge and inland flooding; durable asset resilience; potential insurance premium reductions for protected zones.
# - Limitations/risks: high capital intensity, environmental/shoreline alteration, long permitting cycles, maintenance burden, risk of protection gaps without comprehensive ecosystem integration.
#
# 2) Managed retreat and targeted relocation (MR): buyouts, relocation assistance, zoning adjustments, incentive programs
# - Upfront cost: ~$1.2–2.5 billion (buyouts and early relocation subsidies over 5–15 years).
# - Recurring costs: ~$20–60 million/year (program administration, housing assistance, social services).
# - Benefits: reduces exposure for the most vulnerable/fragile populations and properties; preserves open space and community fabric in the most at-risk zones; lowers long-term hardening needs in those zones.
# - Limitations/risks: political and community opposition; potential displacement and affordability concerns; land-use rewiring challenges; may not address non-residential assets.
#
# 3) Nature-based/hybrid solutions (NBH): living shorelines, wetlands/restoration, dune enhancement, green streets, permeable surfaces, floodable parks
# - Upfront cost: ~$0.6–2.0 billion (pilot-scale to citywide); costs scale with area and maintenance needs.
# - Recurring costs: ~$10–40 million/year (restoration maintenance, vegetation management, monitoring, adaptive maintenance).
# - Benefits: co-benefits (habitat, recreation, water quality, carbon sequestration, cooler urban microclimates); flexibility and lower long-term protection costs; buffers multiple climate hazards; lower social disruption than retreat.
# - Limitations: performance variability under extreme events; long lead times for full ecosystem function; ongoing stewardship and funding required; some areas require complementary hard infrastructure.
#
# (Recommendation: adopt NBH as primary strategy with phased, scalable hard protections in critical nodes and a pre-identified MR option for the most exposed neighborhoods. This hybrid reduces risk from climate surprises and supports equity while providing a faster, modular path to protection.)
#
# (c) Prioritized, time-phased implementation plan (with decision triggers)
#
# Phase A: 0–5 years (foundation)
# - Actions: risk and equity mapping; establish resilience governance (a resilience office or authority); pilot NBH projects (living shorelines, dune restoration, green streets) in 2–3 exposure corridors; begin protected-site selection for hardening; start community engagement focused on low-income neighborhoods.
# - Milestones: baseline vulnerability inventory; pilot NBH sites fully designed; initial buyout/relocation framework ready for a subset of lowest-income zones; funding plan and bonds issued for initial NBH and small-scale hardening.
# - Decision triggers: if NBH pilots underperform predicted flood reduction by >25% in major events, pivot to more aggressive hybrid hardening in those segments; if equity indicators lag, accelerate targeted MR with expanded housing support.
#
# Phase B: 5–10 years (scale NBH; advance selective hardening)
# - Actions: expand NBH networks; implement green/blue infrastructure in city corridors; begin hardening at critical assets (hospitals, wastewater, pumping stations) with modular seawalls or flood barriers; launch targeted MR (voluntary buyouts) in highest-risk neighborhoods; formalize funding streams.
# - Milestones: 25–40% of high-risk zones NBH-protected; critical asset ring hardened; first wave of buyouts completed; financing tools in place for long-term capital.
# - Decision triggers: if protective performance against design storms remains below targets, escalate hardening in additional corridors; if political consensus falters, pause non-essential MR and reallocate to NBH/hardening.
#
# Phase C: 10–20 years (integrated protection; adaptive management)
# - Actions: complete major NBH networks; implement major hardening where cost-effective; complete remainder MR programs where benefits exceed costs; implement floodable parks and water-sensitive urban design citywide.
# - Milestones: protection of majority of at-risk assets in core districts; significant expansion of protective NBH in fringe communities; insurance/premium reductions realized in protected areas.
# - Decision triggers: if climate data indicate new risk profiles or if MR uptake stalls, adjust incentives; if procurement or construction costs spike, trigger value-engineering reviews and extended financing strategies.
#
# Phase D: 20–30 years (assessment and adaptation)
# - Actions: performance review; retrofits to meet updated climate projections; adjust protection mix as needed; scale monitoring; ensure long-term maintenance and equity safeguards.
# - Milestones: ≥90% of prioritized assets protected; resilience monitoring system operational; outcomes report showing reduced damages and improved equity metrics.
# - Decision triggers: if 2055 protection target is not on track, implement rapid deployment of additional NBH or restore MR options with updated incentives.
#
# (d) Financing the plan fairly (instruments and distributional impact)
#
# - Capital instruments
#   - General obligation bonds (GO): long-term funding for NBH and selective hard infrastructure; repaid via property taxes; prioritize equitable allocation to disadvantaged neighborhoods.
#   - Resilience bonds / catastrophe bonds: transfer risk to markets; align with insurance savings.
#   - Federal/state grants and programs: FEMA HMA/BRIC, HUD CDBG-DR/HOME, NOAA; seek multi-year commitments and tied resilience planning.
#   - Public-private partnerships (P3) and developer obligations: impact fees, density bonuses linked to resilience improvements; reinvestment requirements in nearshore districts.
#   - Stormwater utility charges: modest, progressive rate structure to fund NBH and green infrastructure; ensure exemptions or caps for very low-income residents.
#   - Reinvested insurance and disaster recovery windfalls: reserve funds for hardening in subsequent cycles.
#
# - Distributional safeguards
#   - Reserve at least 25–40% of resilience funds for low-income neighborhoods; prioritize home buyouts, relocation assistance, and rent-support programs.
#   - Anti-displacement measures: affordable-housing protections, tenant-rights advocacy, and community benefit agreements with developers.
#   - Transparent oversight: independent equity advisory board, public dashboards, annual progress reports.
#
# (e) Top five uncertainties and mitigation measures
# 1) Climate projections and extreme events: uncertainty in SLR and storm intensity.
#    - Mitigation: design with modularity, adaptive thresholds, staged deployments, and regular re-evaluation every 5–7 years.
# 2) Financing gaps and political gridlock.
#    - Mitigation: diversify funding (federal/state grants, resilience bonds, private contributions), establish a resilience fund with dedicated revenue streams.
# 3) Public opposition to retreat/displacement.
#    - Mitigation: robust, early community engagement; fair compensation, mobility and housing assistance, clear non-displacement commitments where feasible.
# 4) NBH performance under extreme events and maintenance burden.
#    - Mitigation: durable designs, long-term maintenance contracts, adaptive management, robust monitoring, and rapid repair provisions.
# 5) Equity and displacement risks.
#    - Mitigation: explicit equity targets, rent/price controls around protected zones, anti-displacement programs, community land trusts, and inclusive decision-making.
#
# (f) Core assumptions and probability of protection
# Core assumptions
# - SLR and storm intensities follow mid-to-high warming scenarios but with adaptive protections capable of upgrading every 5–7 years.
# - Population remains around 500,000 with modest migration; housing affordability policies are in place.
# - Technology costs trend with current trajectories for NBH and modular hardening; financing markets remain accessible.
# - Federal/state support remains available and implementing agencies meet procurement timelines.
#
# Probability estimate for primary approach
# - Primary approach: Nature-based/hybrid with targeted hardening and MR as a contingency.
# - Credible probability that this primary approach will protect ≥90% of at-risk urban assets by 2055: about 70–80%, with about a 20–30% chance that more aggressive hardening or greater retreat becomes necessary due to climate surprises or funding shortfalls.
# Rationale: NBH plus selective hardening provides flexible, scalable protection, aligns with multiple co-benefits (ecology, recreation, water quality), and can be deployed incrementally while expanding protections. Displacement risk is mitigated with targeted MR and robust equity safeguards. The remaining risk hinges on extreme events beyond design, funding volatility, or political inertia.
#
# If you’d like, I can tailor the cost ranges, milestones, and equity targets to your city’s actual budget, tax structure, and FEMA/State grant programs, and draft a concise one-page decision matrix to facilitate council votes.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gpt-5-nano

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
